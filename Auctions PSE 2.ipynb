# %%
import numpy as np
import pandas as pd
import os
import math
import sweetviz as sv

# %%
os.chdir('/Users/krzysztofwasniewski/Desktop/Aukcje PSE 2')

# %%
os.listdir()
# Out:
# ['Auction 2028 AN.xlsx',
#  'Auction2026 AN.xlsx',
#  'Auction2022.xlsx',
#  'Auction2023.xlsx',
#  'Auction2027 AN.xlsx',
#  'Auction2024.xlsx',
#  'Auction2025 AN.xlsx',
#  'Auction2024 AN.xlsx',
#  'Auction2025.xlsx',
#  'Auction2026.xlsx',
#  'Auction2021 AN.xlsx',
#  'Auction2027.xlsx',
#  'Auction 2028.xlsx',
#  'Auction2022 AN.xlsx',
#  'Auction2021.xlsx',
#  'Auction2023 AN.xlsx']

# %%
A2028=pd.DataFrame(pd.read_excel('Auction 2028 AN.xlsx'))
A2028.insert(0,"DY",2028)

A2026=pd.DataFrame(pd.read_excel('Auction2026 AN.xlsx'))
A2026.insert(0,"DY",2026)

A2027=pd.DataFrame(pd.read_excel('Auction2027 AN.xlsx'))
A2027.insert(0,"DY",2027)

A2025=pd.DataFrame(pd.read_excel('Auction2025 AN.xlsx'))
A2025.insert(0,"DY",2025)

A2024=pd.DataFrame(pd.read_excel('Auction2024 AN.xlsx'))
A2024.insert(0,"DY",2024)

A2021=pd.DataFrame(pd.read_excel('Auction2021 AN.xlsx'))
A2021.insert(0,"DY",2021)

A2022=pd.DataFrame(pd.read_excel('Auction2022 AN.xlsx'))
A2022.insert(0,"DY",2022)

A2023=pd.DataFrame(pd.read_excel('Auction2023 AN.xlsx'))
A2023.insert(0,"DY",2023)

# %%
A2021_2028=pd.concat([A2021,A2022,A2023,A2024,A2025,A2026,A2027,A2028])

# %%
A2021_2028.replace('Niepotwierdzona','niepotwierdzona')
A2021_2028.replace('Istniejąca jednostka rynku mocy_x000D_wytwórcza','istniejąca jednostka rynku mocy_wytwórcza')
A2021_2028.replace('Nowa jednostka rynku mocy_x000D_wytwórcza','nowa jednostka rynku mocy wytwórcza')
# Out:
#        DY  Cena zamknięcia aukcji za 1 kW Kod  jednostki rynku mocy  \
# 0    2021                          240.32                   JRM/296
# 1    2021                          240.32                   JRM/231
# 2    2021                          240.32                   JRM/233
# 3    2021                          240.32                    JRM/96
# 4    2021                          240.32                    JRM/68
# ..    ...                             ...                       ...
# 154  2028                          244.90                   JRM/437
# 155  2028                          244.90                   JRM/886
# 156  2028                          244.90                   JRM/238
# 157  2028                          244.90                   JRM/240
# 158  2028                          244.90                   JRM/921
#
#                               Typ jednostki rynku mocy  \
# 0      Istniejąca jednostka rynku mocy_x000D_wytwórcza
# ...

# %%
A2021_2028.to_excel('A2021_2028.xlsx')

# %%
A2021_2028=pd.DataFrame(pd.read_excel('A2021_2028.xlsx'))

# %%
A2021_2028.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 874 entries, 0 to 873
# Data columns (total 8 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   DY                                         874 non-null    int64
#  1   Cena zamknięcia aukcji za 1 kW             874 non-null    float64
#  2   Kod  jednostki rynku mocy                  874 non-null    object
#  3   Typ jednostki rynku mocy                   874 non-null    object
#  4   Wielkość obowiązku mocowego [MW]           874 non-null    float64
#  5   Okres trwania obowiązku mocowego w latach  874 non-null    float64
#  6   Nazwa dostawcy mocy                        874 non-null    object
#  7   Total committment                          874 non-null    float64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 54.8+ KB

# %%
my_report = sv.analyze(A2021_2028)
my_report.show_notebook()
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.7.1 | (c) OpenJS Foundation and other contributors | jquery.org/license */
# ...
